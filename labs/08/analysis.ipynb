# %%
# !pip install scikit-learn pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\alicj\anaconda\lib\site-packages (1.5.1)
# Requirement already satisfied: pandas in c:\users\alicj\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\alicj\anaconda\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\alicj\anaconda\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\alicj\anaconda\lib\site-packages (0.13.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\alicj\anaconda\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\alicj\anaconda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alicj\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alicj\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alicj\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alicj\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alicj\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alicj\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alicj\anaconda\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alicj\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\alicj\anaconda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\alicj\anaconda\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alicj\anaconda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\alicj\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://archive.ics.uci.edu/static/public/2/data.csv"

data = pd.read_csv(url, header=None)

# %%
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
           'marital-status', 'occupation', 'relationship', 'race', 'sex',
           'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']

data.columns = columns

# %%
# Altersverteilung
plt.figure(figsize=(8,5))
sns.histplot(data['age'], bins=20, kde=True)
plt.title("Altersverteilung")
plt.xlabel("Alter")
plt.ylabel("Anzahl Personen")
plt.show()

# %%
# Einkommen nach Geschlecht
plt.figure(figsize=(6,5))
sns.countplot(x='income', hue='sex', data=data)
plt.title("Einkommen nach Geschlecht")
plt.show()
